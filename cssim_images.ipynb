# %%
# %matplotlib widget
from cssim import open_gui
open_gui()

# %%
# %matplotlib widget
from cssim import open_gui
open_gui("diagrams/first_order_step.json")
T = 1
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=d7ffe19607d545b49032cffc21303bd2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# VBox(children=(HBox(children=(Button(button_style='success', description=' Run', icon='play', layout=Layout(wi…

# %%
import importlib
import cssim

cssim = importlib.reload(cssim)
data = cssim.load_json("diagrams/first_order_step.json")
G = cssim.build_graph(data)
cssim.draw_graph(G,seed=4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
from cssim import open_gui
open_gui("diagrams/first_order_step_1.json")
T = 1
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=2f0edb8c0b374555b9290d05cca9d30a"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# VBox(children=(HBox(children=(Button(button_style='success', description=' Run', icon='play', layout=Layout(wi…

# %%
# %matplotlib widget
from cssim import open_gui, interactive_plot
open_gui("diagrams/derivative.json")
Kp = 1
Td = 1
J = 1
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=afa841d4e1a54509826308d5d6c675ad"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# VBox(children=(HBox(children=(Button(button_style='success', description=' Run', icon='play', layout=Layout(wi…

# %%
import importlib
import cssim

cssim = importlib.reload(cssim)
data = cssim.load_json("diagrams/derivative.json")
G = cssim.build_graph(data)
cssim.draw_graph(G,seed=9)
