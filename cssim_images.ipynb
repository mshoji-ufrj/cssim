# %%
# %matplotlib widget
from cssim import open_gui
open_gui()

# %%
# %matplotlib widget
from cssim import open_gui
open_gui("diagrams/first_order_step.json")
T = 1
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=d7ffe19607d545b49032cffc21303bd2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# VBox(children=(HBox(children=(Button(button_style='success', description=' Run', icon='play', layout=Layout(wi…

# %%
import importlib
import cssim

cssim = importlib.reload(cssim)
data = cssim.load_json("diagrams/first_order_step.json")
G = cssim.build_graph(data)
cssim.draw_graph(G,seed=4)
# Out:
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …

# %%
# %matplotlib widget
from cssim import open_gui
open_gui("diagrams/first_order_step.json")
T = 1
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=f51459769d0a4ef38619a0a6239544b2"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# VBox(children=(HBox(children=(Button(button_style='success', description=' Run', icon='play', layout=Layout(wi…

# %% [markdown]
# $i$-ésimo bloco
#
# $k$-ésima entrada externa
#
# $u_k$
#
# $v_i$
#
# $w_i$
#
# $u_1$
#
# $u_2$
#
# $\vdots$
#
# $u_r$
#
# $v_{1,a}$
#
# $v_{1,b}$
#
# $v_2$
#
# $\vdots$
#
# $v_m$
#
# $w_1$
#
# $w_2$
#
# $\vdots$
#
# $w_m$
