# %%
# %matplotlib widget
from cssim import open_gui
open_gui()
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=1ce3718e58944453a5c5145d25fbc285"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ...
