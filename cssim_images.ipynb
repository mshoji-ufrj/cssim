# %%
# %matplotlib widget
from cssim import open_gui
open_gui()
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=6c515522ca15489382a08907c65f2662"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ...
