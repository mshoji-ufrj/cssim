# %%
# %matplotlib widget
from cssim import open_gui
open_gui()
# Out:
#         <iframe
#             width="100%"
#             height="700"
#             src="http://localhost:8000/?session=fdf2384b03e341b2b52715756e254d1d"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
# ...
